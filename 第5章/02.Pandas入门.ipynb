# %%
import pandas as pd

# 构造DataFrame -- 创建数据集(学员成绩信息)

df = pd.DataFrame([
    {"姓名": "小王", "语文": 90, "数学": 80, "英语": 70},
    {"姓名": "小李", "语文": 80, "数学": 90, "英语": 70},
    {"姓名": "小张", "语文": 80, "数学": 70, "英语": 90},
    {"姓名": "小赵", "语文": 70, "数学": 80, "英语": 90},
    {"姓名": "小钱", "语文": 95, "数学": 70, "英语": 60},
    {"姓名": "小孙", "语文": 70, "数学": 80, "英语": 90},
    {"姓名": "小周", "语文": 80, "数学": 90, "英语": 75},
    {"姓名": "小吴", "语文": 90, "数学": 70, "英语": 80},
    {"姓名": "小郑", "语文": 80, "数学": 70, "英语": 90},
])

# 统计计算
print(f"语文最高分: {df['语文'].max()}, 语文最低分: {df['语文'].min()}, 语文平均分: {df['语文'].mean():.2f}")
print(f"数学最高分: {df['数学'].max()}, 数学最低分: {df['数学'].min()}, 数学平均分: {df['数学'].mean():.2f}")
print(f"英语最高分: {df['英语'].max()}, 英语最低分: {df['英语'].min()}, 英语平均分: {df['英语'].mean():.2f}")
# Out:
# 语文最高分: 95, 语文最低分: 70, 语文平均分: 81.67
# 数学最高分: 90, 数学最低分: 70, 数学平均分: 77.78
# 英语最高分: 90, 英语最低分: 60, 英语平均分: 79.44
